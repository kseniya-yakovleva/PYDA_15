# %%
import pandas as pd

# %% [markdown]
# * Задание 1  Определите какому фильму было выставлено больше всего оценок 5.0

# %%
ratings = pd.read_csv('ml-latest-small/ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
filter_ratings = ratings[ratings.rating == 5.0]
filter_ratings.head() # фильтр на оценку фильма
# Out:
#    userId  movieId  rating  timestamp
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
# 6       1      101     5.0  964980868
# 8       1      151     5.0  964984041
# 9       1      157     5.0  964984100

# %%
filter_ratings.groupby('movieId').count().sort_values('rating', ascending=False).head()
# Out:
#          userId  rating  timestamp
# movieId
# 318         153     153        153
# 296         123     123        123
# 356         116     116        116
# 2571        109     109        109
# 260         104     104        104

# %% [markdown]
# * Задание 2 По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
power = pd.read_csv('power.csv')
power.head()
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1

# %%
coutries_filter = power[power['country'].isin(['Latvia', 'Estonia', 'Lithuania'])]
coutries_filter.head() # фильтр на страны
# Out:
#        country  year  quantity  category
# 373  Lithuania  2014      39.0         1
# 374  Lithuania  2013     192.0         1
# 375  Lithuania  2012     196.0         1
# 376  Lithuania  2011     171.0         1
# 377  Lithuania  2010     158.0         1

# %%
filer_quantity = coutries_filter[(coutries_filter.quantity > 0)] #значения потребления больше 0
filer_quantity.tail()
# Out:
#            country  year  quantity  category
# 1188857  Lithuania  2008     131.0        71
# 1188858  Lithuania  2007     106.0        71
# 1188859  Lithuania  2006      14.0        71
# 1188860  Lithuania  2005       2.0        71
# 1188861  Lithuania  2004       1.0        71

# %%
filter_year = filer_quantity[(filer_quantity.year > 2005)|(filer_quantity.year < 2010)]
filter_year.head() #фильтр на период 2005-2010
# Out:
#        country  year  quantity  category
# 373  Lithuania  2014      39.0         1
# 374  Lithuania  2013     192.0         1
# 375  Lithuania  2012     196.0         1
# 376  Lithuania  2011     171.0         1
# 377  Lithuania  2010     158.0         1

# %%
category_filter = filter_year[(filter_year.category == 4)|(filter_year.category == 12)|(filter_year.category == 21)]
category_filter.quantity.sum() # фильтр по категориям и сумма из значений
# Out:
# 970728.0

# %% [markdown]
# * Задание 3

# %%
page_url = 'https://www.finanz.ru/valyuty/v-realnom-vremeni'
df = pd.read_html(page_url, attrs = {'class': 'quote_list'}, encoding='utf-8')
df
# Out:
# [    Unnamed: 0              Рубль  Предложение  Спрос  Предыдущее закрытие  \
#  0          NaN            GBP/RUB      1018506      -              1012966
#  1          NaN            EUR/RUB       912215      -               908950
#  2          NaN            USD/RUB       763490      -               760085
#  3          NaN            JPY/RUB        07320      -                07305
#  4          NaN            CNY/RUB       116060      -               115568
#  5          NaN            CHF/RUB       842673      -               840389
#  6          NaN               Евро  Предложение  Спрос  Предыдущее закрытие
#  7          NaN            EUR/USD        11947      -                11964
#  8          NaN            EUR/GBP        08955      -                08979
#  9          NaN            EUR/JPY      1246050      -              1245100
#  10         NaN            EUR/CHF        10827      -                10820
# ...
